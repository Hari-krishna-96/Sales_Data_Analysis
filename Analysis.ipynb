# %%
import pandas as pd
import os
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ## Read all files from the main Sales_Data directory

# %%
files = [file for file in os.listdir('./Data/')]

for each_file in files:
    print(each_file)
# Out:
# Sales_April_2019.csv
# Sales_August_2019.csv
# Sales_December_2019.csv
# Sales_February_2019.csv
# Sales_January_2019.csv
# Sales_July_2019.csv
# Sales_June_2019.csv
# Sales_March_2019.csv
# Sales_May_2019.csv
# Sales_November_2019.csv
# Sales_October_2019.csv
# Sales_September_2019.csv

# %%
all_month_data = pd.DataFrame()       # all_month_data is our empty dataframe

# %% [markdown]
# ## Concatenate each sales data into one complete dataset

# %%
for each_file in files:
    sales_data = pd.read_csv(f"./Data/{each_file}")
    all_month_data = pd.concat([all_month_data, sales_data])

# %%
all_month_data            # we will be working on this dataset
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# ...

# %%
all_month_data.shape
# Out:
# (186850, 6)

# %%
#save the complete dataset to a .csv file for further use 
all_month_data.to_csv('all_month_data.csv', index=False)

# %%
sales_data = pd.read_csv('all_month_data.csv')
sales_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
columns = sales_data.columns
columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %% [markdown]
# ### Some Data Wrangling Tasks.....

# %%
sales_data.isna()
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 0          False    False             False       False       False
# 1           True     True              True        True        True
# 2          False    False             False       False       False
# 3          False    False             False       False       False
# 4          False    False             False       False       False
# ...          ...      ...               ...         ...         ...
# 186845     False    False             False       False       False
# 186846     False    False             False       False       False
# 186847     False    False             False       False       False
# 186848     False    False             False       False       False
# 186849     False    False             False       False       False
#
#         Purchase Address
# 0                  False
# 1                   True
# 2                  False
# 3                  False
# ...

# %%
sales_data.dropna()
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
sales_data.shape
# Out:
# (186850, 6)

# %%
sales_data.dropna(axis="index", how="all", inplace=True)

# %%
sales_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
sales_data.shape
# Out:
# (186305, 6)

# %%
sales_data.describe()
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count     186305                186305           186305     186305
# unique    178438                    20               10         24
# top     Order ID  USB-C Charging Cable                1      11.95
# freq         355                 21903           168552      21903
#
#         Order Date  Purchase Address
# count       186305            186305
# unique      142396            140788
# top     Order Date  Purchase Address
# freq           355               355

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186305 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 9.9+ MB

# %%
sales_data.loc[180125:180150, 'Product':'Price Each']
# Out:
#                            Product Quantity Ordered Price Each
# 180125            Wired Headphones                2      11.99
# 180126            Wired Headphones                2      11.99
# 180127  Bose SoundSport Headphones                1      99.99
# 180128             ThinkPad Laptop                1     999.99
# 180129      AAA Batteries (4-pack)                1       2.99
# 180130            27in FHD Monitor                1     149.99
# 180131          Macbook Pro Laptop                1       1700
# 180132                      iPhone                1        700
# 180133            Wired Headphones                1      11.99
# 180134  Bose SoundSport Headphones                1      99.99
# 180135                20in Monitor                1     109.99
# 180136        USB-C Charging Cable                1      11.95
# 180137        USB-C Charging Cable                1      11.95
# 180138    Lightning Charging Cable                1      14.95
# ...

# %%
sales_data.set_index('Order ID')
# Out:
#                              Product Quantity Ordered Price Each  \
# Order ID
# 176558          USB-C Charging Cable                2      11.95
# 176559    Bose SoundSport Headphones                1      99.99
# 176560                  Google Phone                1        600
# 176560              Wired Headphones                1      11.99
# 176561              Wired Headphones                1      11.99
# ...                              ...              ...        ...
# 259353        AAA Batteries (4-pack)                3       2.99
# 259354                        iPhone                1        700
# 259355                        iPhone                1        700
# 259356        34in Ultrawide Monitor                1     379.99
# 259357          USB-C Charging Cable                1      11.95
#
#               Order Date                         Purchase Address
# Order ID
# 176558    04/19/19 08:46             917 1st St, Dallas, TX 75001
# ...

# %%
sales_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# # 1. What was the best month for sales? How much was earned that month?

# %%
#Create a new Column named 'Month' 
sales_data['Month'] = sales_data['Order Date'].str[0:2]
sales_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04

# %%
sales_data['Quantity Ordered'].value_counts()
# Out:
# 1                   168552
# 2                    13324
# 3                     2920
# 4                      806
# Quantity Ordered       355
# 5                      236
# 6                       80
# 7                       24
# 8                        5
# 9                        3
# Name: Quantity Ordered, dtype: int64

# %%
filt = sales_data['Quantity Ordered'] == 'Quantity Ordered'
new_df = sales_data.loc[-filt]

# %%
new_df.shape
# Out:
# (185950, 7)

# %%
new_df.loc[filt]
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, Quantity Ordered, Price Each, Order Date, Purchase Address, Month]
# Index: []

# %%
new_df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address Month
# ...

# %%
new_df['Quantity Ordered'].value_counts()
# Out:
# 1    168552
# 2     13324
# 3      2920
# 4       806
# 5       236
# 6        80
# 7        24
# 8         5
# 9         3
# Name: Quantity Ordered, dtype: int64

# %%
new_df['Quantity Ordered'] = new_df['Quantity Ordered'].astype('int32')

# %%
new_df['Price Each'] = new_df['Price Each'].astype('float64')

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186849
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int32
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  object
#  7   Sales             185950 non-null  float64
#  8   City              185950 non-null  object
# dtypes: float64(2), int32(1), object(6)
# memory usage: 13.5+ MB

# %%
new_df['Sales'] = (new_df['Quantity Ordered'] * new_df['Price Each'])

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186849
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int32
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  object
#  7   Sales             185950 non-null  float64
#  8   City              185950 non-null  object
# dtypes: float64(2), int32(1), object(6)
# memory usage: 13.5+ MB

# %%
new_df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address Month   Sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04   11.99
#
#            City
# 0        Dallas
# 2        Boston
# 3   Los Angeles
# 4   Los Angeles
# 5   Los Angeles

# %%
ans_df = new_df.groupby('Month').sum()
ans_df
# Out:
#        Quantity Ordered    Price Each         Sales
# Month
# 01                10903  1.811768e+06  1.822257e+06
# 02                13449  2.188885e+06  2.202022e+06
# 03                17005  2.791208e+06  2.807100e+06
# 04                20558  3.367671e+06  3.390670e+06
# 05                18667  3.135125e+06  3.152607e+06
# 06                15253  2.562026e+06  2.577802e+06
# 07                16072  2.632540e+06  2.647776e+06
# 08                13448  2.230345e+06  2.244468e+06
# 09                13109  2.084992e+06  2.097560e+06
# 10                22703  3.715555e+06  3.736727e+06
# 11                19798  3.180601e+06  3.199603e+06
# 12                28114  4.588415e+06  4.613443e+06

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(12,4))
plt.style.use('fivethirtyeight')


month = ans_df.index
sales = ans_df['Sales']



plt.plot(month, sales, color="#444444", linewidth=2, marker='o')

plt.title('Monthly Sales')
plt.xlabel('Month')
plt.ylabel('Sales in USD')

plt.show()

# %% [markdown]
# # Thus, December was the best month for sales.
# #  and the money earned was more than 45M usd

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 2. Which city had the highest sales?

# %%
new_df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address Month   Sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04   11.99
#
#            City
# 0        Dallas
# 2        Boston
# 3   Los Angeles
# 4   Los Angeles
# 5   Los Angeles

# %%
#Create new Column 'City'
new_df['City'] = new_df['Purchase Address'].apply(lambda x: x.split(',')[1])
new_df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address Month   Sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04   11.99
#
#            City
# 0        Dallas
# 2        Boston
# 3   Los Angeles
# 4   Los Angeles
# 5   Los Angeles

# %%
city_grp = new_df.groupby(['City'])
city_grp['City'].value_counts()
# Out:
# City            City
#  Atlanta         Atlanta          14881
#  Austin          Austin            9905
#  Boston          Boston           19934
#  Dallas          Dallas           14820
#  Los Angeles     Los Angeles      29605
#  New York City   New York City    24876
#  Portland        Portland         12465
#  San Francisco   San Francisco    44732
#  Seattle         Seattle          14732
# Name: City, dtype: int64

# %%
ans_df2 = city_grp['Sales'].sum()
ans_df2.rename('Units')
# Out:
# City
#  Atlanta          2.795499e+06
#  Austin           1.819582e+06
#  Boston           3.661642e+06
#  Dallas           2.767975e+06
#  Los Angeles      5.452571e+06
#  New York City    4.664317e+06
#  Portland         2.320491e+06
#  San Francisco    8.262204e+06
#  Seattle          2.747755e+06
# Name: Units, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.style.use('seaborn')

plt.plot(ans_df2, color='#444444', marker='o', linewidth=2)

plt.title('City wise \n Sales')
plt.xlabel('City')
plt.xticks(rotation='45', size=13)
plt.yticks(size=13)
plt.ylabel('Sales in USD')

plt.show()

# %% [markdown]
# # San Francisco had the highest number of sales.

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 3. Which product was sold the most?

# %%
new_df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address Month   Sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04   11.99
#
#            City
# 0        Dallas
# 2        Boston
# 3   Los Angeles
# 4   Los Angeles
# 5   Los Angeles

# %%
ans_df3 = new_df.groupby(['Product']).sum()
ans_df3 = ans_df3.sort_values(by='Quantity Ordered')

# %%
ans_df3
# Out:
#                             Quantity Ordered  Price Each       Sales
# Product
# LG Dryer                                 646   387600.00   387600.00
# LG Washing Machine                       666   399600.00   399600.00
# Vareebadd Phone                         2068   826000.00   827200.00
# 20in Monitor                            4129   451068.99   454148.71
# ThinkPad Laptop                         4130  4127958.72  4129958.70
# Macbook Pro Laptop                      4728  8030800.00  8037600.00
# Flatscreen TV                           4819  1440000.00  1445700.00
# Google Phone                            5532  3315000.00  3319200.00
# 34in Ultrawide Monitor                  6199  2348718.19  2355558.01
# 27in 4K Gaming Monitor                  6244  2429637.70  2435097.56
# iPhone                                  6849  4789400.00  4794300.00
# 27in FHD Monitor                        7550  1125974.93  1132424.50
# ...

# %%
products = ans_df3.index
quantity = ans_df3['Quantity Ordered']

plt.style.use('seaborn')

plt.barh(products, quantity)
plt.xlabel('Units')
plt.xticks(size=15)
plt.yticks(size=15)

plt.show()

# %% [markdown]
# # More than 30k units of AAA Batteries (4-pack) were sold, making them the highest unit of product sold.

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 4. Which sold product was the most expensive?

# %%
ans_df3 = ans_df3.sort_values(by='Sales')

# %%
products = ans_df3.index
sales = ans_df3['Sales']

plt.style.use('seaborn')

plt.barh(products, sales)
plt.xlabel('Sales in USD')
plt.xticks(size=10)
plt.yticks(size=10)

plt.show()

# %% [markdown]
# # Out of the total products sold, Macbook Pro Laptop was the most expensive.

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 5. In which city is Macbook pro laptop sold the most?

# %%
new_df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address Month   Sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04   11.99
#
#            City
# 0        Dallas
# 2        Boston
# 3   Los Angeles
# 4   Los Angeles
# 5   Los Angeles

# %%
ans_df4 = new_df.groupby(['City'])

# %%
mac_users = ans_df4['Product'].apply(lambda x : x.str.contains('Macbook Pro Laptop').sum())
mac_users
# Out:
# City
#  Atlanta           379
#  Austin            251
#  Boston            478
#  Dallas            382
#  Los Angeles       751
#  New York City     656
#  Portland          337
#  San Francisco    1134
#  Seattle           356
# Name: Product, dtype: int64

# %%
mac_users.sort_values
# Out:
# <bound method Series.sort_values of City
#  Atlanta           379
#  Austin            251
#  Boston            478
#  Dallas            382
#  Los Angeles       751
#  New York City     656
#  Portland          337
#  San Francisco    1134
#  Seattle           356
# Name: Product, dtype: int64>

# %%
plt.style.use('seaborn')

plt.bar(mac_users.index, mac_users, width=0.5)

plt.title('MacBooks Sales \n Across the US')
plt.xlabel('City')
plt.ylabel('Units Sold')

plt.xticks(rotation='45', size=13)
plt.yticks(size=13)

plt.show()

# %% [markdown]
# # SF is the city where MacBooks were sold the most.
